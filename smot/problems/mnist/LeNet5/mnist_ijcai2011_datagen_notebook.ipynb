# %%
import tensorflow as tf

from smot.jupyter import model_reports
from smot.problems.mnist.LeNet5 import lenet5_lib

# %%
# Load (and cache) standard MNIST dataset.
(x_train, y_train), (x_test, y_test) = lenet5_lib.load_LeNet5_datasets()

# %%
model = lenet5_lib.build_LeNet5_model(
    pooling=tf.keras.layers.MaxPooling2D,
)

# Print the model summary.
model.summary()

batch_size = 128
validation_split = 0.2
epochs = 50

datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rotation_range=10,
    shear_range=0.1,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.2,
    validation_split=validation_split,
)
datagen.fit(x_train)

training_generator = datagen.flow(
    x_train,
    y_train,
    subset="training",
    batch_size=batch_size,
)
validation_generator = datagen.flow(
    x_train,
    y_train,
    subset="validation",
    batch_size=batch_size,
)

history = model.fit(
    training_generator,
    validation_data=validation_generator,
    epochs=epochs,
    verbose=1,
)

# Evaluate the model with the test data.
test_loss, test_accuracy = model_reports.model_fit_report(
    model=model,
    history=history,
    test_data=(x_test, y_test),
)
# Out:
# Model: "LeNet5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 6)         156
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 10, 10, 16)        2416
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 400)               0
# _________________________________________________________________
# dense (Dense)                (None, 120)               48120
# _________________________________________________________________
# dense_1 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                850
# =================================================================
# Total params: 61,706
# Trainable params: 61,706
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 375/375 [==============================] - 12s 28ms/step - loss: 1.0254 - accuracy: 0.6720 - val_loss: 0.2410 - val_accuracy: 0.9272
# Epoch 2/50
# 375/375 [==============================] - 10s 27ms/step - loss: 0.2178 - accuracy: 0.9345 - val_loss: 0.1712 - val_accuracy: 0.9469
# Epoch 3/50
# 375/375 [==============================] - 10s 28ms/step - loss: 0.1486 - accuracy: 0.9547 - val_loss: 0.1295 - val_accuracy: 0.9617
# Epoch 4/50
# 375/375 [==============================] - 10s 27ms/step - loss: 0.1276 - accuracy: 0.9608 - val_loss: 0.1192 - val_accuracy: 0.9638
# Epoch 5/50
# 375/375 [==============================] - 10s 27ms/step - loss: 0.1080 - accuracy: 0.9681 - val_loss: 0.1036 - val_accuracy: 0.9691
# Epoch 6/50
# 375/375 [==============================] - 10s 27ms/step - loss: 0.0939 - accuracy: 0.9717 - val_loss: 0.0916 - val_accuracy: 0.9728
# Epoch 7/50
# 375/375 [==============================] - 10s 27ms/step - loss: 0.0889 - accuracy: 0.9726 - val_loss: 0.0834 - val_accuracy: 0.9744
# Epoch 8/50
# 375/375 [==============================] - 10s 27ms/step - loss: 0.0820 - accuracy: 0.9745 - val_loss: 0.0780 - val_accuracy: 0.9764
# Epoch 9/50
# 375/375 [==============================] - 10s 27ms/step - loss: 0.0786 - accuracy: 0.9750 - val_loss: 0.0777 - val_accuracy: 0.9751
# Epoch 10/50
# 375/375 [==============================] - 10s 27ms/step - loss: 0.0708 - accuracy: 0.9780 - val_loss: 0.0716 - val_accuracy: 0.9783
# Epoch 11/50
# 375/375 [==============================] - 10s 27ms/step - loss: 0.0698 - accuracy: 0.9778 - val_loss: 0.0679 - val_accuracy: 0.9786
# Epoch 12/50
# 375/375 [==============================] - 10s 27ms/step - loss: 0.0657 - accuracy: 0.9791 - val_loss: 0.0727 - val_accuracy: 0.9785
# Epoch 13/50
# Epoch 33/50
# 375/375 [==============================] - 10s 28ms/step - loss: 0.0405 - accuracy: 0.9873 - val_loss: 0.0564 - val_accuracy: 0.9835
# Epoch 34/50
# 375/375 [==============================] - 11s 28ms/step - loss: 0.0407 - accuracy: 0.9872 - val_loss: 0.0514 - val_accuracy: 0.9843
# Epoch 35/50
# 375/375 [==============================] - 10s 27ms/step - loss: 0.0397 - accuracy: 0.9871 - val_loss: 0.0530 - val_accuracy: 0.9842
# Epoch 36/50
# 375/375 [==============================] - 10s 27ms/step - loss: 0.0385 - accuracy: 0.9878 - val_loss: 0.0513 - val_accuracy: 0.9843
# Epoch 37/50
# 375/375 [==============================] - 10s 27ms/step - loss: 0.0365 - accuracy: 0.9890 - val_loss: 0.0511 - val_accuracy: 0.9848
# Epoch 38/50
# 375/375 [==============================] - 10s 28ms/step - loss: 0.0377 - accuracy: 0.9880 - val_loss: 0.0596 - val_accuracy: 0.9822
# Epoch 39/50
# 375/375 [==============================] - 10s 28ms/step - loss: 0.0416 - accuracy: 0.9859 - val_loss: 0.0594 - val_accuracy: 0.9834
# Epoch 40/50
# 375/375 [==============================] - 10s 27ms/step - loss: 0.0358 - accuracy: 0.9882 - val_loss: 0.0459 - val_accuracy: 0.9871
# Epoch 41/50
# 375/375 [==============================] - 10s 27ms/step - loss: 0.0404 - accuracy: 0.9870 - val_loss: 0.0500 - val_accuracy: 0.9847
# Epoch 42/50
# 375/375 [==============================] - 10s 28ms/step - loss: 0.0392 - accuracy: 0.9888 - val_loss: 0.0462 - val_accuracy: 0.9860
# Epoch 43/50
# 375/375 [==============================] - 10s 27ms/step - loss: 0.0360 - accuracy: 0.9885 - val_loss: 0.0523 - val_accuracy: 0.9841
# Epoch 44/50
# 375/375 [==============================] - 10s 28ms/step - loss: 0.0362 - accuracy: 0.9889 - val_loss: 0.0584 - val_accuracy: 0.9834
# Epoch 45/50
# 375/375 [==============================] - 10s 28ms/step - loss: 0.0381 - accuracy: 0.9876 - val_loss: 0.0575 - val_accuracy: 0.9835
# Epoch 46/50
# 375/375 [==============================] - 10s 28ms/step - loss: 0.0386 - accuracy: 0.9881 - val_loss: 0.0594 - val_accuracy: 0.9827
# Epoch 47/50
# 375/375 [==============================] - 10s 28ms/step - loss: 0.0319 - accuracy: 0.9899 - val_loss: 0.0553 - val_accuracy: 0.9841
# Epoch 48/50
# 375/375 [==============================] - 10s 28ms/step - loss: 0.0370 - accuracy: 0.9877 - val_loss: 0.0480 - val_accuracy: 0.9856
# Epoch 49/50
# 375/375 [==============================] - 10s 28ms/step - loss: 0.0369 - accuracy: 0.9882 - val_loss: 0.0457 - val_accuracy: 0.9867
# Epoch 50/50
# 375/375 [==============================] - 10s 28ms/step - loss: 0.0330 - accuracy: 0.9904 - val_loss: 0.0477 - val_accuracy: 0.9871
# 313/313 [==============================] - 1s 1ms/step - loss: 0.0249 - accuracy: 0.9921
# Test loss: 0.024944424629211426, Test accuracy: 0.9921000003814697, Error rate: 0.007899999618530273
