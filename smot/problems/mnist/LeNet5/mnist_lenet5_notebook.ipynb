# %%
from smot.jupyter import plot_funcs
from smot.problems.mnist.LeNet5 import lenet5_lib

plot_funcs.set_pyplot_defaults()

# %%
# Load (and cache) standard MNIST dataset.
(x_train, y_train), (x_test, y_test) = lenet5_lib.load_LeNet5_datasets()

# %%
model = lenet5_lib.build_LeNet5_model(optimizer='adam')

# Print the model summary.
model.summary()

history = model.fit(
  x=x_train,
  y=y_train,
  batch_size=128,
  epochs=10,
  verbose=1,
  validation_split=0.2,
)

# Evaluate the model with the test data.
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f"Test loss: {test_loss}, Test accuracy: {test_accuracy}")

plot_funcs.plot_history(history)
# Out:
# Model: "LeNet5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 6)         156
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 10, 10, 16)        2416
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 5, 5, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 400)               0
# _________________________________________________________________
# dense (Dense)                (None, 120)               48120
# _________________________________________________________________
# dense_1 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                850
# =================================================================
# Total params: 61,706
# Trainable params: 61,706
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3931 - accuracy: 0.8847 - val_loss: 0.1965 - val_accuracy: 0.9426
# Epoch 2/10
# 375/375 [==============================] - 1s 4ms/step - loss: 0.1503 - accuracy: 0.9541 - val_loss: 0.1265 - val_accuracy: 0.9617
# Epoch 3/10
# 375/375 [==============================] - 1s 4ms/step - loss: 0.1004 - accuracy: 0.9696 - val_loss: 0.0973 - val_accuracy: 0.9699
# Epoch 4/10
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0733 - accuracy: 0.9772 - val_loss: 0.0803 - val_accuracy: 0.9753
# Epoch 5/10
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0584 - accuracy: 0.9815 - val_loss: 0.0772 - val_accuracy: 0.9762
# Epoch 6/10
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0462 - accuracy: 0.9860 - val_loss: 0.0784 - val_accuracy: 0.9754
# Epoch 7/10
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0397 - accuracy: 0.9874 - val_loss: 0.0654 - val_accuracy: 0.9797
# Epoch 8/10
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0306 - accuracy: 0.9905 - val_loss: 0.0611 - val_accuracy: 0.9815
# Epoch 9/10
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0270 - accuracy: 0.9919 - val_loss: 0.0633 - val_accuracy: 0.9816
# Epoch 10/10
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0225 - accuracy: 0.9930 - val_loss: 0.0727 - val_accuracy: 0.9775
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0640 - accuracy: 0.9799
# Test loss: 0.06404050439596176, Test accuracy: 0.9799000024795532
