# %%
from smot.jupyter import model_reports
from smot.problems.mnist.LeNet5 import lenet5_lib

# %%
# Load (and cache) standard MNIST dataset.
(x_train, y_train), (x_test, y_test) = lenet5_lib.load_LeNet5_datasets()

# %%
model = lenet5_lib.build_LeNet5_model()

# Print the model summary.
model.summary()

history = model.fit(
  x=x_train,
  y=y_train,
  batch_size=128,
  epochs=3,
  verbose=1,
  validation_split=0.2,
)

# Evaluate the model with the test data.
test_loss, test_accuracy = model_reports.model_fit_report(
  model=model,
  history=history,
  test_data=(x_test, y_test),
)
# Out:
# Model: "LeNet5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 6)         156
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 10, 10, 16)        2416
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 5, 5, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 400)               0
# _________________________________________________________________
# dense (Dense)                (None, 120)               48120
# _________________________________________________________________
# dense_1 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                850
# =================================================================
# Total params: 61,706
# Trainable params: 61,706
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3850 - accuracy: 0.8879 - val_loss: 0.1843 - val_accuracy: 0.9448
# Epoch 2/3
# 375/375 [==============================] - 1s 4ms/step - loss: 0.1457 - accuracy: 0.9558 - val_loss: 0.1114 - val_accuracy: 0.9675
# Epoch 3/3
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0970 - accuracy: 0.9710 - val_loss: 0.0887 - val_accuracy: 0.9728
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0805 - accuracy: 0.9762
# Test loss: 0.08050442487001419, Test accuracy: 0.9761999845504761
