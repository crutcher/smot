# %%
import tensorflow as tf

from smot.jupyter import model_reports
from smot.problems.mnist.LeNet5 import lenet5_lib

# %%
# Load (and cache) standard MNIST dataset.
(x_train, y_train), (x_test, y_test) = lenet5_lib.load_LeNet5_datasets()

# %%
model = lenet5_lib.build_LeNet5_model()

# Print the model summary.
model.summary()

history = model.fit(
    x=x_train,
    y=y_train,
    batch_size=128,
    epochs=50,
    verbose=1,
    validation_split=0.2,
)

# Evaluate the model with the test data.
test_loss, test_accuracy = model_reports.model_fit_report(
    model=model,
    history=history,
    test_data=(x_test, y_test),
)
# Out:
# Model: "LeNet5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 28, 28, 6)         156
# _________________________________________________________________
# average_pooling2d_2 (Average (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 10, 10, 16)        2416
# _________________________________________________________________
# average_pooling2d_3 (Average (None, 5, 5, 16)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 400)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 120)               48120
# _________________________________________________________________
# dense_4 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                850
# =================================================================
# Total params: 61,706
# Trainable params: 61,706
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.6816 - accuracy: 0.7992 - val_loss: 0.1741 - val_accuracy: 0.9486
# Epoch 2/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1571 - accuracy: 0.9516 - val_loss: 0.1173 - val_accuracy: 0.9634
# Epoch 3/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0977 - accuracy: 0.9708 - val_loss: 0.0983 - val_accuracy: 0.9703
# Epoch 4/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0737 - accuracy: 0.9768 - val_loss: 0.0739 - val_accuracy: 0.9781
# Epoch 5/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0528 - accuracy: 0.9841 - val_loss: 0.0673 - val_accuracy: 0.9793
# Epoch 6/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0432 - accuracy: 0.9868 - val_loss: 0.0663 - val_accuracy: 0.9797
# Epoch 7/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0336 - accuracy: 0.9898 - val_loss: 0.0675 - val_accuracy: 0.9797
# Epoch 8/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0287 - accuracy: 0.9923 - val_loss: 0.0580 - val_accuracy: 0.9830
# Epoch 9/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0223 - accuracy: 0.9941 - val_loss: 0.0616 - val_accuracy: 0.9820
# Epoch 10/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0185 - accuracy: 0.9943 - val_loss: 0.0612 - val_accuracy: 0.9822
# Epoch 11/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0153 - accuracy: 0.9958 - val_loss: 0.0624 - val_accuracy: 0.9826
# Epoch 12/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0146 - accuracy: 0.9957 - val_loss: 0.0622 - val_accuracy: 0.9838
# Epoch 13/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0125 - accuracy: 0.9963 - val_loss: 0.0741 - val_accuracy: 0.9801
# Epoch 14/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0110 - accuracy: 0.9971 - val_loss: 0.0568 - val_accuracy: 0.9847
# Epoch 15/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0089 - accuracy: 0.9973 - val_loss: 0.0684 - val_accuracy: 0.9834
# Epoch 16/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0092 - accuracy: 0.9973 - val_loss: 0.0572 - val_accuracy: 0.9857
# Epoch 17/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0055 - accuracy: 0.9985 - val_loss: 0.0600 - val_accuracy: 0.9850
# Epoch 18/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0053 - accuracy: 0.9987 - val_loss: 0.0676 - val_accuracy: 0.9830
# Epoch 19/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0065 - accuracy: 0.9982 - val_loss: 0.0688 - val_accuracy: 0.9825
# Epoch 20/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0084 - accuracy: 0.9972 - val_loss: 0.0626 - val_accuracy: 0.9843
# Epoch 21/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0042 - accuracy: 0.9990 - val_loss: 0.0627 - val_accuracy: 0.9841
# Epoch 22/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0030 - accuracy: 0.9995 - val_loss: 0.0616 - val_accuracy: 0.9848
# Epoch 23/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0040 - accuracy: 0.9988 - val_loss: 0.0755 - val_accuracy: 0.9836
# Epoch 24/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0058 - accuracy: 0.9984 - val_loss: 0.0725 - val_accuracy: 0.9839
# Epoch 25/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0067 - accuracy: 0.9978 - val_loss: 0.0775 - val_accuracy: 0.9834
# Epoch 26/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0039 - accuracy: 0.9989 - val_loss: 0.0688 - val_accuracy: 0.9837
# Epoch 27/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0625 - val_accuracy: 0.9857
# Epoch 28/50
# 375/375 [==============================] - 1s 3ms/step - loss: 5.4987e-04 - accuracy: 1.0000 - val_loss: 0.0607 - val_accuracy: 0.9870
# Epoch 29/50
# 375/375 [==============================] - 1s 3ms/step - loss: 2.7443e-04 - accuracy: 1.0000 - val_loss: 0.0617 - val_accuracy: 0.9872
# Epoch 30/50
# 375/375 [==============================] - 1s 3ms/step - loss: 2.1009e-04 - accuracy: 1.0000 - val_loss: 0.0611 - val_accuracy: 0.9873
# Epoch 31/50
# 375/375 [==============================] - 1s 3ms/step - loss: 1.7159e-04 - accuracy: 1.0000 - val_loss: 0.0615 - val_accuracy: 0.9872
# Epoch 32/50
# 375/375 [==============================] - 1s 3ms/step - loss: 1.4762e-04 - accuracy: 1.0000 - val_loss: 0.0619 - val_accuracy: 0.9869
# Epoch 33/50
# 375/375 [==============================] - 1s 2ms/step - loss: 1.1657e-04 - accuracy: 1.0000 - val_loss: 0.0620 - val_accuracy: 0.9872
# Epoch 34/50
# 375/375 [==============================] - 1s 3ms/step - loss: 1.0538e-04 - accuracy: 1.0000 - val_loss: 0.0629 - val_accuracy: 0.9873
# Epoch 35/50
# 375/375 [==============================] - 1s 3ms/step - loss: 9.4003e-05 - accuracy: 1.0000 - val_loss: 0.0633 - val_accuracy: 0.9872
# Epoch 36/50
# 375/375 [==============================] - 1s 3ms/step - loss: 7.4378e-05 - accuracy: 1.0000 - val_loss: 0.0632 - val_accuracy: 0.9869
# Epoch 37/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0242 - accuracy: 0.9932 - val_loss: 0.0785 - val_accuracy: 0.9810
# Epoch 38/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0104 - accuracy: 0.9962 - val_loss: 0.0671 - val_accuracy: 0.9845
# Epoch 39/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0027 - accuracy: 0.9994 - val_loss: 0.0656 - val_accuracy: 0.9854
# Epoch 40/50
# 375/375 [==============================] - 1s 3ms/step - loss: 6.6851e-04 - accuracy: 1.0000 - val_loss: 0.0630 - val_accuracy: 0.9870
# Epoch 41/50
# 375/375 [==============================] - 1s 3ms/step - loss: 4.1107e-04 - accuracy: 1.0000 - val_loss: 0.0621 - val_accuracy: 0.9868
# Epoch 42/50
# 375/375 [==============================] - 1s 3ms/step - loss: 2.4426e-04 - accuracy: 1.0000 - val_loss: 0.0626 - val_accuracy: 0.9868
# Epoch 43/50
# 375/375 [==============================] - 1s 2ms/step - loss: 1.9840e-04 - accuracy: 1.0000 - val_loss: 0.0633 - val_accuracy: 0.9865
# Epoch 44/50
# 375/375 [==============================] - 1s 3ms/step - loss: 1.5802e-04 - accuracy: 1.0000 - val_loss: 0.0634 - val_accuracy: 0.9868
# Epoch 45/50
# 375/375 [==============================] - 1s 3ms/step - loss: 1.2591e-04 - accuracy: 1.0000 - val_loss: 0.0640 - val_accuracy: 0.9872
# Epoch 46/50
# 375/375 [==============================] - 1s 2ms/step - loss: 1.1051e-04 - accuracy: 1.0000 - val_loss: 0.0643 - val_accuracy: 0.9872
# Epoch 47/50
# 375/375 [==============================] - 1s 2ms/step - loss: 1.0226e-04 - accuracy: 1.0000 - val_loss: 0.0647 - val_accuracy: 0.9872
# Epoch 48/50
# 375/375 [==============================] - 1s 2ms/step - loss: 8.5555e-05 - accuracy: 1.0000 - val_loss: 0.0650 - val_accuracy: 0.9872
# Epoch 49/50
# 375/375 [==============================] - 1s 3ms/step - loss: 7.1267e-05 - accuracy: 1.0000 - val_loss: 0.0654 - val_accuracy: 0.9876
# Epoch 50/50
# 375/375 [==============================] - 1s 2ms/step - loss: 6.1560e-05 - accuracy: 1.0000 - val_loss: 0.0665 - val_accuracy: 0.9871
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0521 - accuracy: 0.9893
# Test loss: 0.05213053151965141, Test accuracy: 0.989300012588501, Error rate: 0.010699987411499023
