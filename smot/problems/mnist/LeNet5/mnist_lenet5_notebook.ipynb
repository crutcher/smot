# %%
from smot.jupyter import model_reports
from smot.problems.mnist.LeNet5 import lenet5_lib

# %%
# Load (and cache) standard MNIST dataset.
(x_train, y_train), (x_test, y_test) = lenet5_lib.load_LeNet5_datasets()

# %%
model = lenet5_lib.build_LeNet5_model()

# Print the model summary.
model.summary()

history = model.fit(
  x=x_train,
  y=y_train,
  batch_size=128,
  epochs=20,
  verbose=1,
  validation_split=0.2,
)

# Evaluate the model with the test data.
test_loss, test_accuracy = model_reports.model_fit_report(
  model=model,
  history=history,
  test_data=(x_test, y_test),
)
# Out:
# Model: "LeNet5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 28, 28, 6)         156
# _________________________________________________________________
# average_pooling2d_2 (Average (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 10, 10, 16)        2416
# _________________________________________________________________
# average_pooling2d_3 (Average (None, 5, 5, 16)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 400)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 120)               48120
# _________________________________________________________________
# dense_4 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                850
# =================================================================
# Total params: 61,706
# Trainable params: 61,706
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3696 - accuracy: 0.8933 - val_loss: 0.1771 - val_accuracy: 0.9465
# Epoch 2/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.1411 - accuracy: 0.9571 - val_loss: 0.1087 - val_accuracy: 0.9680
# Epoch 3/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0931 - accuracy: 0.9712 - val_loss: 0.0882 - val_accuracy: 0.9735
# Epoch 4/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0674 - accuracy: 0.9788 - val_loss: 0.0741 - val_accuracy: 0.9778
# Epoch 5/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0535 - accuracy: 0.9835 - val_loss: 0.0628 - val_accuracy: 0.9808
# Epoch 6/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0426 - accuracy: 0.9873 - val_loss: 0.0720 - val_accuracy: 0.9781
# Epoch 7/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0352 - accuracy: 0.9892 - val_loss: 0.0575 - val_accuracy: 0.9837
# Epoch 8/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0293 - accuracy: 0.9909 - val_loss: 0.0566 - val_accuracy: 0.9828
# Epoch 9/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0241 - accuracy: 0.9922 - val_loss: 0.0639 - val_accuracy: 0.9814
# Epoch 10/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0209 - accuracy: 0.9941 - val_loss: 0.0598 - val_accuracy: 0.9821
# Epoch 11/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0163 - accuracy: 0.9951 - val_loss: 0.0593 - val_accuracy: 0.9829
# Epoch 12/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0149 - accuracy: 0.9956 - val_loss: 0.0530 - val_accuracy: 0.9848
# Epoch 13/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0117 - accuracy: 0.9967 - val_loss: 0.0512 - val_accuracy: 0.9851
# Epoch 14/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0087 - accuracy: 0.9977 - val_loss: 0.0577 - val_accuracy: 0.9844
# Epoch 15/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0092 - accuracy: 0.9973 - val_loss: 0.0585 - val_accuracy: 0.9841
# Epoch 16/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0089 - accuracy: 0.9972 - val_loss: 0.0529 - val_accuracy: 0.9861
# Epoch 17/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0053 - accuracy: 0.9986 - val_loss: 0.0629 - val_accuracy: 0.9838
# Epoch 18/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0070 - accuracy: 0.9980 - val_loss: 0.0544 - val_accuracy: 0.9858
# Epoch 19/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0057 - accuracy: 0.9984 - val_loss: 0.0640 - val_accuracy: 0.9854
# Epoch 20/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0117 - accuracy: 0.9962 - val_loss: 0.0698 - val_accuracy: 0.9825
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0644 - accuracy: 0.9830
# Test loss: 0.06444157660007477, Test accuracy: 0.9829999804496765
