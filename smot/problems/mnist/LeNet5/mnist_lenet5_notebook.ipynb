# %%
from smot.jupyter import model_reports
from smot.problems.mnist.LeNet5 import lenet5_lib

# %%
# Load (and cache) standard MNIST dataset.
(x_train, y_train), (x_test, y_test) = lenet5_lib.load_LeNet5_datasets()

# %%
model = lenet5_lib.build_LeNet5_model()

# Print the model summary.
model.summary()

history = model.fit(
  x=x_train,
  y=y_train,
  batch_size=128,
  epochs=20,
  verbose=1,
  validation_split=0.2,
)

# Evaluate the model with the test data.
test_loss, test_accuracy = model_reports.model_fit_report(
  model=model,
  history=history,
  test_data=(x_test, y_test),
)
# Out:
# Model: "LeNet5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 6)         156
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 10, 10, 16)        2416
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 5, 5, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 400)               0
# _________________________________________________________________
# dense (Dense)                (None, 120)               48120
# _________________________________________________________________
# dense_1 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                850
# =================================================================
# Total params: 61,706
# Trainable params: 61,706
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 375/375 [==============================] - 14s 13ms/step - loss: 0.7052 - accuracy: 0.7940 - val_loss: 0.1852 - val_accuracy: 0.9441
# Epoch 2/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1658 - accuracy: 0.9505 - val_loss: 0.1139 - val_accuracy: 0.9659
# Epoch 3/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0991 - accuracy: 0.9699 - val_loss: 0.0944 - val_accuracy: 0.9707
# Epoch 4/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0713 - accuracy: 0.9781 - val_loss: 0.0774 - val_accuracy: 0.9759
# Epoch 5/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0515 - accuracy: 0.9849 - val_loss: 0.0670 - val_accuracy: 0.9796
# Epoch 6/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0431 - accuracy: 0.9864 - val_loss: 0.0617 - val_accuracy: 0.9808
# Epoch 7/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0352 - accuracy: 0.9895 - val_loss: 0.0662 - val_accuracy: 0.9803
# Epoch 8/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0298 - accuracy: 0.9907 - val_loss: 0.0575 - val_accuracy: 0.9829
# Epoch 9/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0237 - accuracy: 0.9925 - val_loss: 0.0564 - val_accuracy: 0.9828
# Epoch 10/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0185 - accuracy: 0.9943 - val_loss: 0.0583 - val_accuracy: 0.9831
# Epoch 11/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0161 - accuracy: 0.9953 - val_loss: 0.0513 - val_accuracy: 0.9854
# Epoch 12/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0137 - accuracy: 0.9963 - val_loss: 0.0574 - val_accuracy: 0.9835
# Epoch 13/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0133 - accuracy: 0.9958 - val_loss: 0.0667 - val_accuracy: 0.9817
# Epoch 14/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0119 - accuracy: 0.9962 - val_loss: 0.0555 - val_accuracy: 0.9846
# Epoch 15/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0076 - accuracy: 0.9981 - val_loss: 0.0579 - val_accuracy: 0.9846
# Epoch 16/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0069 - accuracy: 0.9979 - val_loss: 0.0593 - val_accuracy: 0.9848
# Epoch 17/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0047 - accuracy: 0.9991 - val_loss: 0.0683 - val_accuracy: 0.9830
# Epoch 18/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0084 - accuracy: 0.9971 - val_loss: 0.0620 - val_accuracy: 0.9851
# Epoch 19/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0072 - accuracy: 0.9978 - val_loss: 0.0696 - val_accuracy: 0.9823
# Epoch 20/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0076 - accuracy: 0.9981 - val_loss: 0.0689 - val_accuracy: 0.9841
# 313/313 [==============================] - 10s 16ms/step - loss: 0.0529 - accuracy: 0.9850
# Test loss: 0.052937768399715424, Test accuracy: 0.9850000143051147, Error rate: 0.014999985694885254
