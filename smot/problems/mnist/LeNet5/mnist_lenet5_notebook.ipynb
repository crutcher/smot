# %%
import tensorflow as tf

from smot.jupyter import model_reports
from smot.problems.mnist.LeNet5 import lenet5_lib

# %%
# Load (and cache) standard MNIST dataset.
(x_train, y_train), (x_test, y_test) = lenet5_lib.load_LeNet5_datasets()

# %%
model = lenet5_lib.build_LeNet5_model()

# Print the model summary.
model.summary()

history = model.fit(
    x=x_train,
    y=y_train,
    batch_size=128,
    epochs=20,
    verbose=1,
    validation_split=0.2,
)

# Evaluate the model with the test data.
test_loss, test_accuracy = model_reports.model_fit_report(
    model=model,
    history=history,
    test_data=(x_test, y_test),
)
# Out:
# Model: "LeNet5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 6)         156
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 10, 10, 16)        2416
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 5, 5, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 400)               0
# _________________________________________________________________
# dense (Dense)                (None, 120)               48120
# _________________________________________________________________
# dense_1 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                850
# =================================================================
# Total params: 61,706
# Trainable params: 61,706
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 375/375 [==============================] - 5s 3ms/step - loss: 0.7075 - accuracy: 0.7955 - val_loss: 0.1941 - val_accuracy: 0.9433
# Epoch 2/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1722 - accuracy: 0.9485 - val_loss: 0.1215 - val_accuracy: 0.9632
# Epoch 3/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1045 - accuracy: 0.9695 - val_loss: 0.0895 - val_accuracy: 0.9728
# Epoch 4/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0718 - accuracy: 0.9793 - val_loss: 0.0779 - val_accuracy: 0.9763
# Epoch 5/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0554 - accuracy: 0.9831 - val_loss: 0.0678 - val_accuracy: 0.9805
# Epoch 6/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0418 - accuracy: 0.9875 - val_loss: 0.0639 - val_accuracy: 0.9811
# Epoch 7/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0337 - accuracy: 0.9896 - val_loss: 0.0667 - val_accuracy: 0.9802
# Epoch 8/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0257 - accuracy: 0.9921 - val_loss: 0.0608 - val_accuracy: 0.9819
# Epoch 9/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0211 - accuracy: 0.9941 - val_loss: 0.0581 - val_accuracy: 0.9828
# Epoch 10/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0174 - accuracy: 0.9951 - val_loss: 0.0617 - val_accuracy: 0.9822
# Epoch 11/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0145 - accuracy: 0.9958 - val_loss: 0.0577 - val_accuracy: 0.9829
# Epoch 12/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0106 - accuracy: 0.9969 - val_loss: 0.0587 - val_accuracy: 0.9842
# Epoch 13/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0104 - accuracy: 0.9969 - val_loss: 0.0662 - val_accuracy: 0.9809
# Epoch 14/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0072 - accuracy: 0.9981 - val_loss: 0.0542 - val_accuracy: 0.9855
# Epoch 15/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0079 - accuracy: 0.9978 - val_loss: 0.0667 - val_accuracy: 0.9833
# Epoch 16/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0068 - accuracy: 0.9983 - val_loss: 0.0636 - val_accuracy: 0.9826
# Epoch 17/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0052 - accuracy: 0.9988 - val_loss: 0.0693 - val_accuracy: 0.9824
# Epoch 18/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0059 - accuracy: 0.9982 - val_loss: 0.0652 - val_accuracy: 0.9843
# Epoch 19/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0063 - accuracy: 0.9981 - val_loss: 0.0716 - val_accuracy: 0.9818
# Epoch 20/20
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0040 - accuracy: 0.9988 - val_loss: 0.0719 - val_accuracy: 0.9819
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0563 - accuracy: 0.9842
# Test loss: 0.05625605955719948, Test accuracy: 0.9842000007629395, Error rate: 0.015799999237060547
