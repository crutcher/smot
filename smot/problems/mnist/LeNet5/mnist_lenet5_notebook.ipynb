# %%
import tensorflow as tf

from smot.jupyter import model_reports
from smot.problems.mnist.LeNet5 import lenet5_lib

# %%
# Load (and cache) standard MNIST dataset.
(x_train, y_train), (x_test, y_test) = lenet5_lib.load_LeNet5_datasets()

# %%
strategy = tf.distribute.MirroredStrategy()
print("Number of devices: {}".format(strategy.num_replicas_in_sync))

with strategy.scope():
    model = lenet5_lib.build_LeNet5_model()

# Print the model summary.
model.summary()

history = model.fit(
    x=x_train,
    y=y_train,
    batch_size=128,
    epochs=20,
    verbose=1,
    validation_split=0.2,
)

# Evaluate the model with the test data.
test_loss, test_accuracy = model_reports.model_fit_report(
    model=model,
    history=history,
    test_data=(x_test, y_test),
)
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# Number of devices: 2
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Model: "LeNet5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 6)         156
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 10, 10, 16)        2416
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 5, 5, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 400)               0
# _________________________________________________________________
# dense (Dense)                (None, 120)               48120
# _________________________________________________________________
# dense_1 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                850
# =================================================================
# Total params: 61,706
# Trainable params: 61,706
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# INFO:tensorflow:batch_all_reduce: 10 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:batch_all_reduce: 10 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# 375/375 [==============================] - 8s 7ms/step - loss: 0.6515 - accuracy: 0.8230 - val_loss: 0.1740 - val_accuracy: 0.9488
# Epoch 2/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.1555 - accuracy: 0.9525 - val_loss: 0.1109 - val_accuracy: 0.9666
# Epoch 3/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0956 - accuracy: 0.9711 - val_loss: 0.0827 - val_accuracy: 0.9753
# Epoch 4/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0660 - accuracy: 0.9807 - val_loss: 0.0736 - val_accuracy: 0.9774
# Epoch 5/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0519 - accuracy: 0.9842 - val_loss: 0.0727 - val_accuracy: 0.9790
# Epoch 6/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0413 - accuracy: 0.9876 - val_loss: 0.0661 - val_accuracy: 0.9804
# Epoch 7/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0327 - accuracy: 0.9899 - val_loss: 0.0643 - val_accuracy: 0.9812
# Epoch 8/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0256 - accuracy: 0.9921 - val_loss: 0.0600 - val_accuracy: 0.9823
# Epoch 9/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0228 - accuracy: 0.9930 - val_loss: 0.0638 - val_accuracy: 0.9819
# Epoch 10/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0187 - accuracy: 0.9941 - val_loss: 0.0608 - val_accuracy: 0.9814
# Epoch 11/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0163 - accuracy: 0.9957 - val_loss: 0.0584 - val_accuracy: 0.9830
# Epoch 12/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0148 - accuracy: 0.9958 - val_loss: 0.0626 - val_accuracy: 0.9827
# Epoch 13/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0127 - accuracy: 0.9962 - val_loss: 0.0677 - val_accuracy: 0.9808
# Epoch 14/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0097 - accuracy: 0.9973 - val_loss: 0.0606 - val_accuracy: 0.9824
# Epoch 15/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0083 - accuracy: 0.9980 - val_loss: 0.0598 - val_accuracy: 0.9839
# Epoch 16/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0056 - accuracy: 0.9988 - val_loss: 0.0590 - val_accuracy: 0.9853
# Epoch 17/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0048 - accuracy: 0.9988 - val_loss: 0.0709 - val_accuracy: 0.9822
# Epoch 18/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0080 - accuracy: 0.9976 - val_loss: 0.0646 - val_accuracy: 0.9818
# Epoch 19/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0083 - accuracy: 0.9973 - val_loss: 0.0632 - val_accuracy: 0.9832
# Epoch 20/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0058 - accuracy: 0.9983 - val_loss: 0.0676 - val_accuracy: 0.9834
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0502 - accuracy: 0.9852
# Test loss: 0.050203826278448105, Test accuracy: 0.9851999878883362, Error rate: 0.014800012111663818
