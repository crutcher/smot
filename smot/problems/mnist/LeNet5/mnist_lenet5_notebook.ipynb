# %%
import tensorflow as tf

from smot.jupyter import model_reports
from smot.problems.mnist.LeNet5 import lenet5_lib

# %%
# Load (and cache) standard MNIST dataset.
(x_train, y_train), (x_test, y_test) = lenet5_lib.load_LeNet5_datasets()

# %%
model = lenet5_lib.build_LeNet5_model()

# Print the model summary.
model.summary()

history = model.fit(
    x=x_train,
    y=y_train,
    batch_size=128,
    epochs=50,
    verbose=1,
    validation_split=0.2,
)

# Evaluate the model with the test data.
test_loss, test_accuracy = model_reports.model_fit_report(
    model=model,
    history=history,
    test_data=(x_test, y_test),
)
# Out:
# Model: "LeNet5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 6)         156
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 10, 10, 16)        2416
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 5, 5, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 400)               0
# _________________________________________________________________
# dense (Dense)                (None, 120)               48120
# _________________________________________________________________
# dense_1 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                850
# =================================================================
# Total params: 61,706
# Trainable params: 61,706
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 375/375 [==============================] - 3s 3ms/step - loss: 0.6858 - accuracy: 0.7996 - val_loss: 0.1825 - val_accuracy: 0.9433
# Epoch 2/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1627 - accuracy: 0.9518 - val_loss: 0.1166 - val_accuracy: 0.9657
# Epoch 3/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1029 - accuracy: 0.9693 - val_loss: 0.0877 - val_accuracy: 0.9730
# Epoch 4/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0758 - accuracy: 0.9774 - val_loss: 0.0881 - val_accuracy: 0.9719
# Epoch 5/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0576 - accuracy: 0.9824 - val_loss: 0.0639 - val_accuracy: 0.9812
# Epoch 6/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0448 - accuracy: 0.9864 - val_loss: 0.0635 - val_accuracy: 0.9803
# Epoch 7/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0376 - accuracy: 0.9887 - val_loss: 0.0569 - val_accuracy: 0.9824
# Epoch 8/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0304 - accuracy: 0.9904 - val_loss: 0.0606 - val_accuracy: 0.9820
# Epoch 9/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0262 - accuracy: 0.9919 - val_loss: 0.0576 - val_accuracy: 0.9817
# Epoch 10/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0230 - accuracy: 0.9928 - val_loss: 0.0569 - val_accuracy: 0.9823
# Epoch 11/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0196 - accuracy: 0.9939 - val_loss: 0.0555 - val_accuracy: 0.9839
# Epoch 12/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0162 - accuracy: 0.9950 - val_loss: 0.0523 - val_accuracy: 0.9845
# Epoch 13/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0140 - accuracy: 0.9959 - val_loss: 0.0564 - val_accuracy: 0.9836
# Epoch 14/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0114 - accuracy: 0.9968 - val_loss: 0.0548 - val_accuracy: 0.9844
# Epoch 15/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0093 - accuracy: 0.9977 - val_loss: 0.0570 - val_accuracy: 0.9833
# Epoch 16/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0083 - accuracy: 0.9977 - val_loss: 0.0542 - val_accuracy: 0.9844
# Epoch 17/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0076 - accuracy: 0.9982 - val_loss: 0.0613 - val_accuracy: 0.9836
# Epoch 18/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0087 - accuracy: 0.9974 - val_loss: 0.0659 - val_accuracy: 0.9823
# Epoch 19/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0099 - accuracy: 0.9968 - val_loss: 0.0579 - val_accuracy: 0.9841
# Epoch 20/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0052 - accuracy: 0.9987 - val_loss: 0.0537 - val_accuracy: 0.9868
# Epoch 21/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0054 - accuracy: 0.9983 - val_loss: 0.0551 - val_accuracy: 0.9851
# Epoch 22/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0026 - accuracy: 0.9995 - val_loss: 0.0555 - val_accuracy: 0.9867
# Epoch 23/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0020 - accuracy: 0.9996 - val_loss: 0.0638 - val_accuracy: 0.9852
# Epoch 24/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0089 - accuracy: 0.9969 - val_loss: 0.0713 - val_accuracy: 0.9823
# Epoch 25/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0065 - accuracy: 0.9978 - val_loss: 0.0662 - val_accuracy: 0.9849
# Epoch 26/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0035 - accuracy: 0.9991 - val_loss: 0.0673 - val_accuracy: 0.9831
# Epoch 27/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.0600 - val_accuracy: 0.9854
# Epoch 28/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.0556 - val_accuracy: 0.9874
# Epoch 29/50
# 375/375 [==============================] - 1s 3ms/step - loss: 4.2123e-04 - accuracy: 1.0000 - val_loss: 0.0631 - val_accuracy: 0.9862
# Epoch 30/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0100 - accuracy: 0.9966 - val_loss: 0.0710 - val_accuracy: 0.9843
# Epoch 31/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0100 - accuracy: 0.9964 - val_loss: 0.0680 - val_accuracy: 0.9849
# Epoch 32/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0033 - accuracy: 0.9991 - val_loss: 0.0614 - val_accuracy: 0.9863
# Epoch 33/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.0582 - val_accuracy: 0.9865
# Epoch 34/50
# 375/375 [==============================] - 1s 3ms/step - loss: 3.8531e-04 - accuracy: 1.0000 - val_loss: 0.0582 - val_accuracy: 0.9872
# Epoch 35/50
# 375/375 [==============================] - 1s 3ms/step - loss: 2.2656e-04 - accuracy: 1.0000 - val_loss: 0.0581 - val_accuracy: 0.9877
# Epoch 36/50
# 375/375 [==============================] - 1s 3ms/step - loss: 1.7837e-04 - accuracy: 1.0000 - val_loss: 0.0579 - val_accuracy: 0.9879
# Epoch 37/50
# 375/375 [==============================] - 1s 3ms/step - loss: 1.4642e-04 - accuracy: 1.0000 - val_loss: 0.0583 - val_accuracy: 0.9877
# Epoch 38/50
# 375/375 [==============================] - 1s 3ms/step - loss: 1.2380e-04 - accuracy: 1.0000 - val_loss: 0.0586 - val_accuracy: 0.9879
# Epoch 39/50
# 375/375 [==============================] - 1s 3ms/step - loss: 1.0835e-04 - accuracy: 1.0000 - val_loss: 0.0587 - val_accuracy: 0.9881
# Epoch 40/50
# 375/375 [==============================] - 1s 3ms/step - loss: 8.8499e-05 - accuracy: 1.0000 - val_loss: 0.0590 - val_accuracy: 0.9881
# Epoch 41/50
# 375/375 [==============================] - 1s 3ms/step - loss: 7.8294e-05 - accuracy: 1.0000 - val_loss: 0.0591 - val_accuracy: 0.9881
# Epoch 42/50
# 375/375 [==============================] - 1s 3ms/step - loss: 6.9668e-05 - accuracy: 1.0000 - val_loss: 0.0600 - val_accuracy: 0.9883
# Epoch 43/50
# 375/375 [==============================] - 1s 3ms/step - loss: 6.3110e-05 - accuracy: 1.0000 - val_loss: 0.0604 - val_accuracy: 0.9880
# Epoch 44/50
# 375/375 [==============================] - 1s 3ms/step - loss: 4.9695e-05 - accuracy: 1.0000 - val_loss: 0.0612 - val_accuracy: 0.9880
# Epoch 45/50
# 375/375 [==============================] - 1s 3ms/step - loss: 4.1877e-05 - accuracy: 1.0000 - val_loss: 0.0615 - val_accuracy: 0.9884
# Epoch 46/50
# 375/375 [==============================] - 1s 3ms/step - loss: 3.6237e-05 - accuracy: 1.0000 - val_loss: 0.0607 - val_accuracy: 0.9889
# Epoch 47/50
# 375/375 [==============================] - 1s 3ms/step - loss: 3.0835e-05 - accuracy: 1.0000 - val_loss: 0.0621 - val_accuracy: 0.9886
# Epoch 48/50
# 375/375 [==============================] - 1s 3ms/step - loss: 2.7319e-05 - accuracy: 1.0000 - val_loss: 0.0691 - val_accuracy: 0.9868
# Epoch 49/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0345 - accuracy: 0.9905 - val_loss: 0.0725 - val_accuracy: 0.9847
# Epoch 50/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0098 - accuracy: 0.9971 - val_loss: 0.0659 - val_accuracy: 0.9845
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0596 - accuracy: 0.9857
# Test loss: 0.059550415724515915, Test accuracy: 0.9857000112533569, Error rate: 0.014299988746643066
