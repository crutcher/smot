# %%
from smot.jupyter import model_reports
from smot.problems.mnist.LeNet5 import lenet5_lib

# %%
# Load (and cache) standard MNIST dataset.
(x_train, y_train), (x_test, y_test) = lenet5_lib.load_LeNet5_datasets()

# %%
model = lenet5_lib.build_LeNet5_model()

# Print the model summary.
model.summary()

history = model.fit(
  x=x_train,
  y=y_train,
  batch_size=128,
  epochs=20,
  verbose=1,
  validation_split=0.2,
)

# Evaluate the model with the test data.
test_loss, test_accuracy = model_reports.model_fit_report(
  model=model,
  history=history,
  test_data=(x_test, y_test),
)
# Out:
# Model: "LeNet5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 6)         156
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 10, 10, 16)        2416
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 5, 5, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 400)               0
# _________________________________________________________________
# dense (Dense)                (None, 120)               48120
# _________________________________________________________________
# dense_1 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                850
# =================================================================
# Total params: 61,706
# Trainable params: 61,706
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3847 - accuracy: 0.8889 - val_loss: 0.1809 - val_accuracy: 0.9456
# Epoch 2/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.1391 - accuracy: 0.9576 - val_loss: 0.1080 - val_accuracy: 0.9659
# Epoch 3/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0915 - accuracy: 0.9724 - val_loss: 0.0832 - val_accuracy: 0.9743
# Epoch 4/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0663 - accuracy: 0.9802 - val_loss: 0.0780 - val_accuracy: 0.9768
# Epoch 5/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0545 - accuracy: 0.9834 - val_loss: 0.0642 - val_accuracy: 0.9793
# Epoch 6/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0404 - accuracy: 0.9879 - val_loss: 0.0599 - val_accuracy: 0.9810
# Epoch 7/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0333 - accuracy: 0.9898 - val_loss: 0.0574 - val_accuracy: 0.9817
# Epoch 8/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0281 - accuracy: 0.9915 - val_loss: 0.0609 - val_accuracy: 0.9814
# Epoch 9/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0226 - accuracy: 0.9928 - val_loss: 0.0599 - val_accuracy: 0.9814
# Epoch 10/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0193 - accuracy: 0.9942 - val_loss: 0.0618 - val_accuracy: 0.9822
# Epoch 11/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0179 - accuracy: 0.9946 - val_loss: 0.0633 - val_accuracy: 0.9832
# Epoch 12/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0136 - accuracy: 0.9962 - val_loss: 0.0604 - val_accuracy: 0.9827
# Epoch 13/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0115 - accuracy: 0.9967 - val_loss: 0.0677 - val_accuracy: 0.9812
# Epoch 14/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0105 - accuracy: 0.9969 - val_loss: 0.0613 - val_accuracy: 0.9836
# Epoch 15/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0082 - accuracy: 0.9977 - val_loss: 0.0604 - val_accuracy: 0.9836
# Epoch 16/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0081 - accuracy: 0.9976 - val_loss: 0.0583 - val_accuracy: 0.9851
# Epoch 17/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0068 - accuracy: 0.9981 - val_loss: 0.0608 - val_accuracy: 0.9852
# Epoch 18/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0060 - accuracy: 0.9982 - val_loss: 0.0644 - val_accuracy: 0.9838
# Epoch 19/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0088 - accuracy: 0.9975 - val_loss: 0.0610 - val_accuracy: 0.9847
# Epoch 20/20
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0058 - accuracy: 0.9982 - val_loss: 0.0629 - val_accuracy: 0.9848
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0566 - accuracy: 0.9853
# Test loss: 0.05657193437218666, Test accuracy: 0.9853000044822693
