# %%
import tensorflow as tf

from smot.jupyter import model_reports
from smot.problems.mnist.LeNet5 import lenet5_lib

# %%
# Load (and cache) standard MNIST dataset.
(x_train, y_train), (x_test, y_test) = lenet5_lib.load_LeNet5_datasets()

# %%
model = lenet5_lib.build_LeNet5_model()

# Print the model summary.
model.summary()

callbacks = [
    tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3),
]

history = model.fit(
    x=x_train,
    y=y_train,
    batch_size=128,
    epochs=50,
    verbose=1,
    validation_split=0.2,
    callbacks = callbacks,
)

# Evaluate the model with the test data.
test_loss, test_accuracy = model_reports.model_fit_report(
    model=model,
    history=history,
    test_data=(x_test, y_test),
)
# Out:
# Model: "LeNet5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 28, 28, 6)         156
# _________________________________________________________________
# average_pooling2d_2 (Average (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 10, 10, 16)        2416
# _________________________________________________________________
# average_pooling2d_3 (Average (None, 5, 5, 16)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 400)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 120)               48120
# _________________________________________________________________
# dense_4 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                850
# =================================================================
# Total params: 61,706
# Trainable params: 61,706
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.6737 - accuracy: 0.8075 - val_loss: 0.1649 - val_accuracy: 0.9533
# Epoch 2/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1545 - accuracy: 0.9520 - val_loss: 0.1118 - val_accuracy: 0.9661
# Epoch 3/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0952 - accuracy: 0.9723 - val_loss: 0.0870 - val_accuracy: 0.9746
# Epoch 4/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0722 - accuracy: 0.9784 - val_loss: 0.0736 - val_accuracy: 0.9775
# Epoch 5/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0538 - accuracy: 0.9840 - val_loss: 0.0653 - val_accuracy: 0.9799
# Epoch 6/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0419 - accuracy: 0.9874 - val_loss: 0.0664 - val_accuracy: 0.9790
# Epoch 7/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0343 - accuracy: 0.9888 - val_loss: 0.0613 - val_accuracy: 0.9812
# Epoch 8/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0273 - accuracy: 0.9915 - val_loss: 0.0607 - val_accuracy: 0.9822
# Epoch 9/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0221 - accuracy: 0.9939 - val_loss: 0.0584 - val_accuracy: 0.9831
# Epoch 10/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0178 - accuracy: 0.9952 - val_loss: 0.0602 - val_accuracy: 0.9827
# Epoch 11/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0149 - accuracy: 0.9961 - val_loss: 0.0553 - val_accuracy: 0.9835
# Epoch 12/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0144 - accuracy: 0.9957 - val_loss: 0.0595 - val_accuracy: 0.9841
# Epoch 13/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0112 - accuracy: 0.9967 - val_loss: 0.0564 - val_accuracy: 0.9843
# Epoch 14/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0091 - accuracy: 0.9973 - val_loss: 0.0661 - val_accuracy: 0.9824
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0532 - accuracy: 0.9842
# Test loss: 0.053216759115457535, Test accuracy: 0.9842000007629395, Error rate: 0.015799999237060547
