# %%
import tensorflow as tf

from smot.jupyter import model_reports
from smot.problems.mnist import mnist_lib

# %%
# Load (and cache) standard MNIST dataset.
(x_train, y_train), (x_test, y_test) = mnist_lib.load_LeNet5_datasets()

# %%
model = mnist_lib.build_LeNet5_model()

# Print the model summary.
model.summary()

callbacks = [
    tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=3),
]

history = model.fit(
    x=x_train,
    y=y_train,
    batch_size=128,
    epochs=50,
    verbose=1,
    validation_split=0.2,
    callbacks=callbacks,
)

# Evaluate the model with the test data.
test_loss, test_accuracy = model_reports.model_fit_report(
    model=model,
    history=history,
    test_data=(x_test, y_test),
)
# Out:
# Model: "LeNet5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 6)         156
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 10, 10, 16)        2416
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 5, 5, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 400)               0
# _________________________________________________________________
# dense (Dense)                (None, 120)               48120
# _________________________________________________________________
# dense_1 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                850
# =================================================================
# Total params: 61,706
# Trainable params: 61,706
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 375/375 [==============================] - 3s 3ms/step - loss: 0.6945 - accuracy: 0.8115 - val_loss: 0.1842 - val_accuracy: 0.9438
# Epoch 2/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1639 - accuracy: 0.9507 - val_loss: 0.1307 - val_accuracy: 0.9597
# Epoch 3/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0995 - accuracy: 0.9704 - val_loss: 0.0915 - val_accuracy: 0.9723
# Epoch 4/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0699 - accuracy: 0.9796 - val_loss: 0.0765 - val_accuracy: 0.9763
# Epoch 5/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0533 - accuracy: 0.9848 - val_loss: 0.0664 - val_accuracy: 0.9805
# Epoch 6/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0409 - accuracy: 0.9882 - val_loss: 0.0771 - val_accuracy: 0.9770
# Epoch 7/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0347 - accuracy: 0.9892 - val_loss: 0.0630 - val_accuracy: 0.9817
# Epoch 8/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0283 - accuracy: 0.9917 - val_loss: 0.0597 - val_accuracy: 0.9831
# Epoch 9/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0225 - accuracy: 0.9933 - val_loss: 0.0618 - val_accuracy: 0.9827
# Epoch 10/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0186 - accuracy: 0.9945 - val_loss: 0.0567 - val_accuracy: 0.9844
# Epoch 11/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0160 - accuracy: 0.9954 - val_loss: 0.0551 - val_accuracy: 0.9834
# Epoch 12/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0145 - accuracy: 0.9953 - val_loss: 0.0564 - val_accuracy: 0.9852
# Epoch 13/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0107 - accuracy: 0.9970 - val_loss: 0.0599 - val_accuracy: 0.9833
# Epoch 14/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0092 - accuracy: 0.9976 - val_loss: 0.0560 - val_accuracy: 0.9845
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0461 - accuracy: 0.9855
# Test loss: 0.04613412916660309, Test accuracy: 0.9854999780654907, Error rate: 0.014500021934509277
